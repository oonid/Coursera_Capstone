# %% [markdown]
# <a href="https://colab.research.google.com/github/oonid/Coursera_Capstone/blob/main/The_Battle_of_Neighborhoods/The_Battle_of_Neighbourhoods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Battle of Neighbourhoods
#
# Applied Data Science Capstone. Coursera. IBM.

# %% [markdown]
# # Analyzing Medical Facilities in New York City Neighbourhoods
#
# Author: oon arfiandwi
#
# Date: 7th March, 2021
#
# Repository: [The Battle of Neighbourhoods](https://github.com/oonid/Coursera_Capstone/tree/main/The_Battle_of_Neighborhoods)

# %% [markdown]
# ## Table of Contents
#
# 1. Understanding New York Dataset with Boroughs and Neighbourhoods.
# 2. Working with Foursquare API to Get Medical Center Categories Data
# 3. Build and Map Nearby Venues
# 4. Analyze Each Neighbourhood
# 5. Cluster Neighbourhoods
# 6. Examine Clusters

# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# Since 2020, pandemics change many things in our lives, everything would be different especially if it is related to health and medicine.
#
# For anyone that has a plan to move to the new city, one of the top questions that would be searched is how far the place from the medical facilities and what type of medical facilities is available in that neighbourhoods.
#
# Through this capstone project, I will be analyzing medical venues in the neighbourhoods of New York City, with the support information from the Foursquare data.
#
# This project would be valuable for anyone that lives and work (also for anyone that plans to be lived or worked) in the neighbourhoods of New York City.

# %% [markdown]
# # Data

# %% [markdown]
# Here's the data which been used in this capstone project.
#
# *   New York City Boroughs and Neighbourhoods data. The data were already available through the course.
#
# *   Foursquare API explore endpoint to get medical venues for every borough listed on New York City dataset.
#
# Note that Foursquare data for [medical categories](https://developer.foursquare.com/docs/build-with-foursquare/categories/) have limitations if we want to get the venues related to the neighbourhoods in the New York City data. So the data exploration starts from the boroughs level to get the venues and after the collection is finished then join the data to the nearest neighbour with the minimum distance calculation.

# %%
# Libraries

import pandas as pd
import numpy as np
import requests
import io
import json

# from pandas.io.json import json_normalize  # this is deprecated, use below
from pandas import json_normalize  # tranform JSON file into a pandas dataframe

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# import k-means from clustering stage
from sklearn.cluster import KMeans

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# Foursquare CLIENT_ID and CLIENT_SECRET will be saved as pass
from getpass import getpass

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # 1. Understanding New York Dataset with Boroughs and Neighbourhoods

# %% [markdown]
# #### Get geographical coordinate of New York City

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
ny_latitude = location.latitude
ny_longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'
    .format(ny_latitude, ny_longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %% [markdown]
# #### Get and load New York Neighbourhoods data

# %%
# !wget -q -O 'newyork_data.json' https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json
print('Data downloaded!')

with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

print('Got {} New York boroughs data'.format(len(newyork_data)))

# construct neighbourhoods from features key
neighbourhoods_data = newyork_data['features']
# Out:
# Data downloaded!
# Got 5 New York boroughs data

# %% [markdown]
# #### Transform data into a pandas dataframe

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighbourhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighbourhoods = pd.DataFrame(columns=column_names)

for data in neighbourhoods_data:
    borough = neighbourhood_name = data['properties']['borough'] 
    neighbourhood_name = data['properties']['name']
        
    neighbourhood_latlon = data['geometry']['coordinates']
    neighbourhood_lat = neighbourhood_latlon[1]
    neighbourhood_lon = neighbourhood_latlon[0]
    
    neighbourhoods = neighbourhoods.append({'Borough': borough,
                                          'Neighbourhood': neighbourhood_name,
                                          'Latitude': neighbourhood_lat,
                                          'Longitude': neighbourhood_lon}, ignore_index=True)

neighbourhoods
# Out:
#            Borough Neighbourhood   Latitude  Longitude
# 0            Bronx     Wakefield  40.894705 -73.847201
# 1            Bronx    Co-op City  40.874294 -73.829939
# 2            Bronx   Eastchester  40.887556 -73.827806
# 3            Bronx     Fieldston  40.895437 -73.905643
# 4            Bronx     Riverdale  40.890834 -73.912585
# ..             ...           ...        ...        ...
# 301      Manhattan  Hudson Yards  40.756658 -74.000111
# 302         Queens       Hammels  40.587338 -73.805530
# 303         Queens     Bayswater  40.611322 -73.765968
# 304         Queens  Queensbridge  40.756091 -73.945631
# 305  Staten Island     Fox Hills  40.617311 -74.081740
#
# [306 rows x 4 columns]

# %% [markdown]
# medical center data in Foursquare not complete for all neighbourhoods, that why we focus on boroughs level.
# later on the process we will map it back to the nearest neighbourhoods by calculate the distance.

# %%
# define the dataframe columns
column_names = ['Borough', 'Latitude', 'Longitude'] 

# instantiate the dataframe
boroughs = pd.DataFrame(columns=column_names)

for borough in neighbourhoods['Borough'].unique():
    address = '{}, NY'.format(borough)

    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('The geograpical coordinate of {} are {}, {}.'
        .format(address, latitude, longitude))
    
    boroughs = boroughs.append({'Borough': borough, 'Latitude': latitude,
                                'Longitude': longitude}, ignore_index=True)

boroughs
# Out:
# The geograpical coordinate of Bronx, NY are 40.8466508, -73.8785937.
# The geograpical coordinate of Manhattan, NY are 40.7896239, -73.9598939.
# The geograpical coordinate of Brooklyn, NY are 40.6501038, -73.9495823.
# The geograpical coordinate of Queens, NY are 40.7498243, -73.7976337.
# The geograpical coordinate of Staten Island, NY are 40.5834557, -74.1496048.
#          Borough   Latitude  Longitude
# 0          Bronx  40.846651 -73.878594
# 1      Manhattan  40.789624 -73.959894
# 2       Brooklyn  40.650104 -73.949582
# 3         Queens  40.749824 -73.797634
# 4  Staten Island  40.583456 -74.149605

# %% [markdown]
# #### Create a map of New York with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[ny_latitude, ny_longitude], zoom_start=10)

# add markers to map
for lat, lng, borough in \
        zip(boroughs['Latitude'], boroughs['Longitude'], boroughs['Borough']):
    label = '{}'.format(borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_32dc95e95b3849ea8b519feb04983664%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_32dc95e95b3849ea8b519feb04983664%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_32dc95e95b3849ea8b519feb04983664%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_32dc95e95b3849ea8b519feb04983664%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.7127281%2C%20-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_d3911cb38a044bc9b53871660bb6cfa3%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# # 2. Working with Foursquare API to Get Medical Center Categories Data

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = getpass('Foursquare ID: ') # your Foursquare ID
CLIENT_SECRET = getpass('Foursquare Secret: ') # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
# print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Foursquare ID: ··········
# Foursquare Secret: ··········
# Your credentails:
# CLIENT_ID: I2ZHJ20LEPMTBLGLXWJVRBAG00MW3BQFDK2OA3QYMEFX41YG

# %%
# query medical category in several cities
LIMIT = 100  # Maximum is 100 per query (city)
radius = 5000  # meters, set upper number until every borough returns 100

results = {}
for lat, lng, borough in \
        zip(boroughs['Latitude'], boroughs['Longitude'], boroughs['Borough']):

    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}' \
          '&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}' \
          .format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat,
        lng,
        radius,
        LIMIT,
        "4bf58dd8d48988d104941735")  # Medical Center Categories
    results[borough] = requests.get(url).json()

print('save results from {} boroughs.'.format(boroughs.shape[0]))
# Out:
# save results from 5 boroughs.

# %% [markdown]
# Borrow `get_category_type` function from Foursquare lab, all the information on _items_ key.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# # 3. Build and Map Nearby Venues

# %% [markdown]
# Now we are ready to clean the json and structure it into a _pandas_ dataframe.

# %%
nearby_venues = {}
for lat, lng, borough in \
        zip(boroughs['Latitude'], boroughs['Longitude'], boroughs['Borough']):

    venues = results[borough]['response']['groups'][0]['items']
    nearby_venues[borough] = json_normalize(venues) # flatten JSON

    # filter columns
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat',
                        'venue.location.lng', 'venue.location.address']
    nearby_venues[borough] = nearby_venues[borough].loc[:, filtered_columns]

    # filter the category for each row
    nearby_venues[borough]['venue.categories'] = \
        nearby_venues[borough].apply(get_category_type, axis=1)

    # clean columns
    nearby_venues[borough].columns = \
        [col.split(".")[-1] for col in nearby_venues[borough].columns]

    print('{} venues in {} were returned by Foursquare.'
        .format(nearby_venues[borough].shape[0], borough))

# check on one of the boroughs
print('Nearby venues on Queens')
nearby_venues['Queens']
# Out:
# 100 venues in Bronx were returned by Foursquare.
# 100 venues in Manhattan were returned by Foursquare.
# 100 venues in Brooklyn were returned by Foursquare.
# 100 venues in Queens were returned by Foursquare.
# 100 venues in Staten Island were returned by Foursquare.
# Nearby venues on Queens
#                                                  name  ...                           address
# 0                         NewYork-Presbyterian Queens  ...                     56-45 Main St
# 1                  Ozanam Hall of Queens Nursing Home  ...                     4241 201st St
# 2                               Main Street Radiology  ...          44-01 Francis Lewis Blvd
# 3                          Better Sight Vision Center  ...                      4202 Main St
# 4   NewYork-Presbyterian Medical Group Queens - Pe...  ...  163-03 Horace Harding Expy Ste 5
# ..                                                ...  ...                               ...
# 95                            Cohen's Fashion Optical  ...                   211-51 26th Ave
# 96                  Sanford B Ratner (Sanford Ratner)  ...                20615 Hillside Ave
# 97              Whitestone Physical Therapy of Queens  ...                   150-12 14th Ave
# 98  NewYork-Presbyterian Medical Group Queens - Ca...  ...                    14-02 150th St
# 99                      North Shore LIJ Medical Group  ...     150-55 14th Avenue, 2nd Floor
#
# [100 rows x 5 columns]

# %%
nearby_maps = {}

for borough_lat, borough_lng, borough in \
        zip(boroughs['Latitude'], boroughs['Longitude'], boroughs['Borough']):

    nearby_maps[borough] = folium.Map(location=[borough_lat, borough_lng],
                                       zoom_start=12)

    # add markers to map
    for lat, lng, label in \
            zip(nearby_venues[borough]['lat'], nearby_venues[borough]['lng'],
                nearby_venues[borough]['name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(nearby_maps[borough])  
    print("Show Top 100 from {} total number of medical places in {} (5 km)"
        .format(results[borough]['response']['totalResults'], borough))
# Out:
# Show Top 100 from 182 total number of medical places in Bronx (5 km)
# Show Top 100 from 274 total number of medical places in Manhattan (5 km)
# Show Top 100 from 215 total number of medical places in Brooklyn (5 km)
# Show Top 100 from 181 total number of medical places in Queens (5 km)
# Show Top 100 from 160 total number of medical places in Staten Island (5 km)

# %% [markdown]
# The most medical places are near from Manhattan.

# %%
borough = 'Manhattan'
print("Showing Top 100 medical places in {}".format(borough))
nearby_maps[borough]
# Out:
# Showing Top 100 medical places in Manhattan
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_8be023efac4644b2a902caa73311a972%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8be023efac4644b2a902caa73311a972%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_8be023efac4644b2a902caa73311a972%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_8be023efac4644b2a902caa73311a972%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.7896239%2C%20-73.9598939%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_b1b184d2ea6b4ae1a6e27e8add757d35%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# #### Calculate the minimum distance between Venues and Neighbourhoods

# %%
# vectorized haversine function
def haversine(lat1, lon1, lat2, lon2, to_radians=True, earth_radius=6371):
    """
    slightly modified version: of http://stackoverflow.com/a/29546836/2901002

    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees or in radians)

    All (lat, lon) coordinates must have numeric dtypes and be of equal length.

    """
    if to_radians:
        lat1, lon1, lat2, lon2 = np.radians([lat1, lon1, lat2, lon2])

    a = np.sin((lat2-lat1)/2.0)**2 + \
        np.cos(lat1) * np.cos(lat2) * np.sin((lon2-lon1)/2.0)**2

    return earth_radius * 2 * np.arcsin(np.sqrt(a))

# %% [markdown]
# Iterate for every venues, calculate the distance from the venue to the neighbourhoods with the same borough.

# %%
medical_venues = pd.DataFrame(columns=['name', 'categories', 'lat', 'lng',
                                       'address', 'Borough', 'Neighbourhood',
                                       'Latitude', 'Longitude', 'distance'])

for borough in boroughs['Borough']:
    medical_in_borough = nearby_venues[borough]
    neighbourhoods_by_borough = neighbourhoods[neighbourhoods['Borough'] == 
                                               borough]
    # merge both df with new A
    df_merge = medical_in_borough.assign(A=1) \
        .merge(neighbourhoods_by_borough.assign(A=1), on='A').drop('A', 1) 
    # calculate distance from every rows and add it to new column distance
    df_merge['distance'] = \
        df_merge.apply(lambda d: haversine(d['lat'], d['lng'],
                                           d['Latitude'], d['Longitude']), 1)
    # re-group by name and lat and lng (make sure same name in diffence latlon)
    medical_venues = medical_venues.append(
            df_merge[df_merge['distance'] \
                     .isin(df_merge.groupby(['name', 'lat', 'lng']) \
                           .min()['distance'].values)])

# cleanup
medical_venues.drop(['Latitude', 'Longitude', 'distance'], axis=1, inplace=True)
medical_venues.reset_index(drop=True)
# Out:
#                                                   name  ...        Neighbourhood
# 0                         Montefiore Medical Pavillion  ...              Norwood
# 1    Montefiore Medical Center (Albert Einstein Col...  ...              Norwood
# 2                                   Isabella Geriatric  ...       Morris Heights
# 3                              Bronx VA Medical Center  ...  Kingsbridge Heights
# 4                      Bronx Lebanon - Fulton Division  ...    Claremont Village
# ..                                                 ...  ...                  ...
# 495  NYC Health + Hospitals/Gotham Health, Mariners...  ...         Graniteville
# 496  Physicians First Messages / Medical Answering ...  ...             Old Town
# 497                         Staten Island Dental Group  ...          Willowbrook
# 498                                       New Dorp MRI  ...             New Dorp
# 499                                  Quest Diagnostics  ...           Bulls Head
#
# [500 rows x 7 columns]

# %% [markdown]
# #### Create a map of medical venues in New York with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[ny_latitude, ny_longitude], zoom_start=10)

# add markers to map
for name, lat, lng, borough, neighbourhood in \
        zip(medical_venues['name'], 
            medical_venues['lat'], medical_venues['lng'],
            medical_venues['Borough'], medical_venues['Neighbourhood']):
    label = '{}, {}'.format(name, neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_57ea0340bbf34f10bb29f0840405d32a%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_57ea0340bbf34f10bb29f0840405d32a%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_57ea0340bbf34f10bb29f0840405d32a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_57ea0340bbf34f10bb29f0840405d32a%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.7127281%2C%20-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_5bf9fe28703f442ba4471783adc905f7%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# # 4. Analyze Each Neighbourhood

# %%
# one hot encoding
medical_onehot = pd.get_dummies(medical_venues[['categories']],
                                prefix="", prefix_sep="")

# add neighborhood column back to dataframe
medical_onehot['Neighbourhood'] = medical_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [medical_onehot.columns[-1]] + list(medical_onehot.columns[:-1])
medical_onehot = medical_onehot[fixed_columns]

medical_onehot
# Out:
#             Neighbourhood  Coworking Space  ...  Sandwich Place  Veterinarian
# 7                 Norwood                0  ...               0             0
# 59                Norwood                0  ...               0             0
# 118        Morris Heights                0  ...               0             0
# 207   Kingsbridge Heights                0  ...               0             0
# 253     Claremont Village                0  ...               0             0
# ...                   ...              ...  ...             ...           ...
# 6011         Graniteville                0  ...               0             0
# 6078             Old Town                0  ...               0             0
# 6167          Willowbrook                0  ...               0             0
# 6188             New Dorp                0  ...               0             0
# 6283           Bulls Head                0  ...               0             0
#
# [500 rows x 19 columns]

# %%
medical_grouped = medical_onehot.groupby('Neighbourhood').mean().reset_index()
medical_grouped
# Out:
#        Neighbourhood  Coworking Space  ...  Sandwich Place  Veterinarian
# 0           Allerton              0.0  ...             0.0           0.0
# 1         Auburndale              0.0  ...             0.0           0.0
# 2        Bay Terrace              0.0  ...             0.0           0.0
# 3         Baychester              0.0  ...             0.0           0.0
# 4            Bayside              0.0  ...             0.0           0.0
# ..               ...              ...  ...             ...           ...
# 117   Williamsbridge              0.0  ...             0.0           0.0
# 118      Willowbrook              0.0  ...             0.0           0.0
# 119  Windsor Terrace              0.0  ...             0.0           0.0
# 120          Wingate              0.0  ...             0.0           0.0
# 121        Yorkville              0.0  ...             0.0           0.0
#
# [122 rows x 19 columns]

# %% [markdown]
# #### Let's print each neighborhood along with the top 5 most common venues and put to dataframe

# %%
num_top_venues = 5

for hood in medical_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = medical_grouped[medical_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Allerton----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Auburndale----
#                 venue  freq
# 0     Doctor's Office  0.77
# 1      Medical Center  0.23
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Bay Terrace----
#              venue  freq
# 0  Doctor's Office  0.71
# 1     Optical Shop  0.14
# 2         Hospital  0.14
# 3  Coworking Space  0.00
# 4      Medical Lab  0.00
#
#
# ----Baychester----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Bayside----
#              venue  freq
# 0  Doctor's Office  0.62
# 1   Medical Center  0.25
# 2         Hospital  0.12
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Bedford Park----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Bedford Stuyvesant----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Beechhurst----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Belmont----
#                 venue  freq
# 0            Hospital   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Bloomfield----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Boerum Hill----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Borough Park----
#                 venue  freq
# 0      Medical Center  0.67
# 1     Doctor's Office  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Briarwood----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Bronxdale----
#              venue  freq
# 0  Doctor's Office   0.5
# 1         Hospital   0.5
# 2  Coworking Space   0.0
# 3      Medical Lab   0.0
# 4   Sandwich Place   0.0
#
#
# ----Brownsville----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Bulls Head----
#                      venue  freq
# 0          Doctor's Office  0.75
# 1           Medical Center  0.08
# 2              Medical Lab  0.08
# 3  Health & Beauty Service  0.08
# 4           Sandwich Place  0.00
#
#
# ----Canarsie----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Carnegie Hill----
#                 venue  freq
# 0     Doctor's Office  0.82
# 1      Medical Center  0.18
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Castle Hill----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Castleton Corners----
#                 venue  freq
# 0     Doctor's Office  0.71
# 1      Medical Center  0.29
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Central Harlem----
#                 venue  freq
# 0      Medical Center  0.67
# 1     Doctor's Office  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Chelsea----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Claremont Village----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Clinton----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Clinton Hill----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Co-op City----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----College Point----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Concourse----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Concourse Village----
#              venue  freq
# 0  Doctor's Office   0.6
# 1   Medical Center   0.2
# 2     Fire Station   0.2
# 3      Medical Lab   0.0
# 4   Sandwich Place   0.0
#
#
# ----Corona----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Crown Heights----
#               venue  freq
# 0   Doctor's Office   0.6
# 1    Medical Center   0.2
# 2  Dentist's Office   0.2
# 3       Medical Lab   0.0
# 4    Sandwich Place   0.0
#
#
# ----Ditmas Park----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Dongan Hills----
#                 venue  freq
# 0     Doctor's Office   0.6
# 1      Medical Center   0.4
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----East Harlem----
#              venue  freq
# 0   Medical Center  0.50
# 1  Doctor's Office  0.25
# 2         Hospital  0.25
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Egbertville----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Eltingville----
#              venue  freq
# 0  Doctor's Office   0.6
# 1   Medical Center   0.2
# 2         Hospital   0.2
# 3      Medical Lab   0.0
# 4   Sandwich Place   0.0
#
#
# ----Erasmus----
#              venue  freq
# 0  Doctor's Office  0.50
# 1   Medical Center  0.25
# 2         Hospital  0.25
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Flatbush----
#              venue  freq
# 0  Doctor's Office  0.50
# 1   Medical Center  0.25
# 2         Hospital  0.25
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Flushing----
#                 venue  freq
# 0      Medical Center  0.53
# 1     Doctor's Office  0.47
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Fordham----
#              venue  freq
# 0   Medical Center   0.4
# 1  Doctor's Office   0.4
# 2         Hospital   0.2
# 3      Medical Lab   0.0
# 4   Sandwich Place   0.0
#
#
# ----Forest Hills----
#                      venue  freq
# 0  Health & Beauty Service   1.0
# 1          Coworking Space   0.0
# 2              Medical Lab   0.0
# 3           Sandwich Place   0.0
# 4       Physical Therapist   0.0
#
#
# ----Forest Hills Gardens----
#                 venue  freq
# 0      Medical Center  0.75
# 1     Doctor's Office  0.25
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Fort Greene----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Fresh Meadows----
#              venue  freq
# 0  Doctor's Office  0.50
# 1   Medical Center  0.25
# 2         Hospital  0.25
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Georgetown----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Gowanus----
#                 venue  freq
# 0      Medical Center  0.67
# 1     Doctor's Office  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Graniteville----
#              venue  freq
# 0  Doctor's Office   0.5
# 1         Hospital   0.5
# 2  Coworking Space   0.0
# 3      Medical Lab   0.0
# 4   Sandwich Place   0.0
#
#
# ----Grant City----
#                 venue  freq
# 0     Doctor's Office   0.8
# 1      Medical Center   0.2
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Great Kills----
#                 venue  freq
# 0     Doctor's Office  0.75
# 1      Medical Center  0.25
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Greenridge----
#              venue  freq
# 0  Doctor's Office  0.50
# 1   Medical Center  0.33
# 2          Daycare  0.17
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Heartland Village----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----High  Bridge----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Hillcrest----
#                 venue  freq
# 0     Doctor's Office  0.67
# 1      Medical Center  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Holliswood----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Hudson Yards----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Jamaica Center----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Jamaica Estates----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Jamaica Hills----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Kensington----
#               venue  freq
# 0    Medical Center  0.33
# 1   Doctor's Office  0.33
# 2      Veterinarian  0.33
# 3  Dentist's Office  0.00
# 4        Eye Doctor  0.00
#
#
# ----Kew Gardens Hills----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Kingsbridge----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Kingsbridge Heights----
#              venue  freq
# 0   Medical Center  0.33
# 1  Doctor's Office  0.33
# 2         Hospital  0.33
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Lenox Hill----
#              venue  freq
# 0   Medical Center  0.61
# 1  Doctor's Office  0.33
# 2   Medical School  0.06
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Lincoln Square----
#                 venue  freq
# 0     Doctor's Office  0.67
# 1      Medical Center  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Longwood----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Madison----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Manhattan Terrace----
#                 venue  freq
# 0      Medical Center  0.83
# 1     Doctor's Office  0.17
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Manhattan Valley----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Manor Heights----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Melrose----
#                 venue  freq
# 0     Doctor's Office  0.67
# 1      Medical Center  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Midtown----
#              venue  freq
# 0  Doctor's Office  0.67
# 1   Medical Center  0.17
# 2         Pharmacy  0.17
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Midwood----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Morningside Heights----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Morris Heights----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Morris Park----
#                 venue  freq
# 0      Medical Center  0.50
# 1     Doctor's Office  0.38
# 2      Sandwich Place  0.12
# 3         Medical Lab  0.00
# 4  Physical Therapist  0.00
#
#
# ----Morrisania----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Mount Eden----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Mount Hope----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Murray Hill----
#              venue  freq
# 0  Doctor's Office  0.50
# 1   Medical Center  0.42
# 2         Hospital  0.08
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----New Dorp----
#              venue  freq
# 0  Doctor's Office  0.42
# 1   Medical Center  0.25
# 2      Medical Lab  0.17
# 3     Home Service  0.08
# 4         Hospital  0.08
#
#
# ----New Dorp Beach----
#              venue  freq
# 0     Optical Shop   0.5
# 1         Hospital   0.5
# 2  Coworking Space   0.0
# 3      Medical Lab   0.0
# 4   Sandwich Place   0.0
#
#
# ----New Springville----
#              venue  freq
# 0  Doctor's Office  0.67
# 1         Hospital  0.33
# 2  Coworking Space  0.00
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Norwood----
#              venue  freq
# 0   Medical Center  0.42
# 1  Doctor's Office  0.42
# 2         Hospital  0.17
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Oakland Gardens----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Oakwood----
#                 venue  freq
# 0     Doctor's Office   0.8
# 1      Medical Center   0.2
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Ocean Parkway----
#                 venue  freq
# 0      Medical Center  0.67
# 1     Doctor's Office  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Old Town----
#                 venue  freq
# 0              Office   1.0
# 1     Coworking Space   0.0
# 2             Daycare   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Olinville----
#                 venue  freq
# 0      Medical Center   0.5
# 1     Doctor's Office   0.5
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Park Slope----
#              venue  freq
# 0  Doctor's Office  0.74
# 1   Medical Center  0.16
# 2       Eye Doctor  0.05
# 3         Hospital  0.05
# 4   Medical School  0.00
#
#
# ----Parkchester----
#              venue  freq
# 0  Doctor's Office  0.67
# 1         Hospital  0.33
# 2  Coworking Space  0.00
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Pelham Bay----
#                 venue  freq
# 0     Doctor's Office   0.6
# 1      Medical Center   0.4
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Pelham Gardens----
#                 venue  freq
# 0     Doctor's Office  0.67
# 1      Medical Center  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Pelham Parkway----
#                 venue  freq
# 0     Doctor's Office  0.67
# 1      Medical Center  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Pomonok----
#                 venue  freq
# 0     Doctor's Office  0.78
# 1      Medical Center  0.22
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Prospect Heights----
#              venue  freq
# 0  Doctor's Office  0.75
# 1   Medical Center  0.12
# 2         Hospital  0.12
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Prospect Lefferts Gardens----
#                 venue  freq
# 0     Doctor's Office  0.67
# 1      Medical Center  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Prospect Park South----
#              venue  freq
# 0         Hospital  0.67
# 1  Doctor's Office  0.33
# 2  Coworking Space  0.00
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Queensboro Hill----
#                 venue  freq
# 0     Doctor's Office  0.50
# 1      Medical Center  0.17
# 2  Physical Therapist  0.17
# 3            Hospital  0.17
# 4         Medical Lab  0.00
#
#
# ----Rego Park----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Remsen Village----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Roosevelt Island----
#              venue  freq
# 0   Medical Center  0.57
# 1  Doctor's Office  0.29
# 2         Hospital  0.14
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Soundview----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Spuyten Duyvil----
#              venue  freq
# 0  Doctor's Office  0.67
# 1         Hospital  0.33
# 2  Coworking Space  0.00
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Sunnyside----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Sunset Park----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Sutton Place----
#              venue  freq
# 0   Medical Center  0.43
# 1  Doctor's Office  0.43
# 2       Eye Doctor  0.14
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Tudor City----
#               venue  freq
# 0    Medical Center   0.8
# 1   Coworking Space   0.2
# 2  Dentist's Office   0.0
# 3   Doctor's Office   0.0
# 4        Eye Doctor   0.0
#
#
# ----Unionport----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----University Heights----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Upper East Side----
#              venue  freq
# 0   Medical Center  0.47
# 1  Doctor's Office  0.47
# 2         Hospital  0.07
# 3      Medical Lab  0.00
# 4   Sandwich Place  0.00
#
#
# ----Upper West Side----
#                 venue  freq
# 0      Medical Center  0.67
# 1            Hospital  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Utopia----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Weeksville----
#                 venue  freq
# 0            Hospital   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----West Farms----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Westchester Square----
#                 venue  freq
# 0     Doctor's Office  0.67
# 1      Medical Center  0.33
# 2         Medical Lab  0.00
# 3      Sandwich Place  0.00
# 4  Physical Therapist  0.00
#
#
# ----Westerleigh----
#                 venue  freq
# 0      Medical Center   1.0
# 1             Daycare   0.0
# 2      Sandwich Place   0.0
# 3  Physical Therapist   0.0
# 4            Pharmacy   0.0
#
#
# ----Whitestone----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Williamsbridge----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Willowbrook----
#               venue  freq
# 0   Doctor's Office  0.50
# 1    Medical Center  0.33
# 2  Dentist's Office  0.17
# 3       Medical Lab  0.00
# 4    Sandwich Place  0.00
#
#
# ----Windsor Terrace----
#                 venue  freq
# 0     Doctor's Office   1.0
# 1     Coworking Space   0.0
# 2         Medical Lab   0.0
# 3      Sandwich Place   0.0
# 4  Physical Therapist   0.0
#
#
# ----Wingate----
#              venue  freq
# 0         Hospital  0.43
# 1  Doctor's Office  0.29
# 2   Medical Center  0.14
# 3   Medical School  0.14
# 4      Medical Lab  0.00
#
#
# ----Yorkville----
#              venue  freq
# 0  Doctor's Office   0.4
# 1         Hospital   0.4
# 2   Medical Center   0.2
# 3      Medical Lab   0.0
# 4   Sandwich Place   0.0

# %% [markdown]
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = medical_grouped['Neighbourhood']

for ind in np.arange(medical_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = \
        return_most_common_venues(medical_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#        Neighbourhood  ...   10th Most Common Venue
# 0           Allerton  ...                 Hospital
# 1         Auburndale  ...                 Hospital
# 2        Bay Terrace  ...             Veterinarian
# 3         Baychester  ...                 Hospital
# 4            Bayside  ...             Veterinarian
# ..               ...  ...                      ...
# 117   Williamsbridge  ...                 Hospital
# 118      Willowbrook  ...                 Hospital
# 119  Windsor Terrace  ...                 Hospital
# 120          Wingate  ...  Health & Beauty Service
# 121        Yorkville  ...             Veterinarian
#
# [122 rows x 11 columns]

# %% [markdown]
# # 5. Cluster Neighbourhoods

# %% [markdown]
# Run _k_-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

medical_grouped_clustering = medical_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(medical_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 0, 0, 2, 0, 2, 2, 2, 3, 2], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

medical_merged = medical_venues

# merge medical_grouped with medical_data to add latitude/longitude for each neighborhood
medical_merged = medical_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

medical_merged # check the last columns!
# Out:
#                                                    name  ...   10th Most Common Venue
# 7                          Montefiore Medical Pavillion  ...             Veterinarian
# 59    Montefiore Medical Center (Albert Einstein Col...  ...             Veterinarian
# 118                                  Isabella Geriatric  ...                 Hospital
# 207                             Bronx VA Medical Center  ...             Veterinarian
# 253                     Bronx Lebanon - Fulton Division  ...                 Hospital
# ...                                                 ...  ...                      ...
# 6011  NYC Health + Hospitals/Gotham Health, Mariners...  ...             Veterinarian
# 6078  Physicians First Messages / Medical Answering ...  ...                 Hospital
# 6167                         Staten Island Dental Group  ...                 Hospital
# 6188                                       New Dorp MRI  ...  Health & Beauty Service
# 6283                                  Quest Diagnostics  ...             Fire Station
#
# [500 rows x 18 columns]

# %% [markdown]
# #### Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[ny_latitude, ny_longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in \
        zip(medical_merged['lat'], medical_merged['lng'],
            medical_merged['Neighbourhood'], medical_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_c60578028e2c424abc2495a15283cfe2%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c60578028e2c424abc2495a15283cfe2%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_c60578028e2c424abc2495a15283cfe2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_c60578028e2c424abc2495a15283cfe2%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.7127281%2C%20-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_0d823870fc3047c28a2793f4a35bb614%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# # 6. Examine Clusters

# %% [markdown]
# Now, examine each cluster and determine the discriminating venue categories that distinguish each cluster.

# %% [markdown]
# #### Cluster 0 (red): Doctor's Office

# %%
cluster0 = medical_merged.loc[medical_merged['Cluster Labels'] == 0, medical_merged.columns[[1] + list(range(5, medical_merged.shape[1]))]]
print(cluster0.shape)
cluster0
# Out:
# (194, 14)
#            categories  ... 10th Most Common Venue
# 398          Hospital  ...           Veterinarian
# 790    Medical Center  ...               Hospital
# 1070   Medical Center  ...               Hospital
# 1185   Medical Center  ...               Hospital
# 1433  Doctor's Office  ...           Veterinarian
# ...               ...  ...                    ...
# 5492  Doctor's Office  ...               Hospital
# 5687  Doctor's Office  ...           Veterinarian
# 5768         Hospital  ...           Veterinarian
# 5876         Hospital  ...           Veterinarian
# 6283      Medical Lab  ...           Fire Station
#
# [194 rows x 14 columns]

# %% [markdown]
# #### Cluster 1 (purple): Medical Center

# %%
cluster1 = medical_merged.loc[medical_merged['Cluster Labels'] == 1, medical_merged.columns[[1] + list(range(5, medical_merged.shape[1]))]]
print(cluster1.shape)
cluster1
# Out:
# (43, 14)
#            categories  ... 10th Most Common Venue
# 355    Medical Center  ...               Hospital
# 433    Medical Center  ...               Hospital
# 1272   Medical Center  ...               Hospital
# 1550   Medical Center  ...               Hospital
# 2601   Medical Center  ...               Hospital
# 436    Medical Center  ...           Veterinarian
# 756   Coworking Space  ...           Veterinarian
# 774    Medical Center  ...               Hospital
# 905    Medical Center  ...               Hospital
# 972    Medical Center  ...           Veterinarian
# 1305   Medical Center  ...               Hospital
# 2132         Hospital  ...           Veterinarian
# 2172   Medical Center  ...           Veterinarian
# 3196   Medical Center  ...           Veterinarian
# 3476   Medical Center  ...           Veterinarian
# 3556   Medical Center  ...           Veterinarian
# 3679   Medical Center  ...               Hospital
# 3719   Medical Center  ...               Hospital
# 1457   Medical Center  ...               Hospital
# 1967   Medical Center  ...               Hospital
# 2128   Medical Center  ...               Hospital
# 2338   Medical Center  ...               Hospital
# 2613   Medical Center  ...               Hospital
# 2667   Medical Center  ...               Hospital
# 2737   Medical Center  ...               Hospital
# 3082   Medical Center  ...               Hospital
# 3227   Medical Center  ...               Hospital
# 3577   Medical Center  ...               Hospital
# 4028   Medical Center  ...               Hospital
# 6727  Doctor's Office  ...               Hospital
# 1405   Medical Center  ...               Hospital
# 3904   Medical Center  ...               Hospital
# 4217   Medical Center  ...               Hospital
# 4541   Medical Center  ...               Hospital
# 4890   Medical Center  ...               Hospital
# 5089   Medical Center  ...               Hospital
# 5214   Medical Center  ...               Hospital
# 5413   Medical Center  ...               Hospital
# 5575   Medical Center  ...               Hospital
# 5863   Medical Center  ...               Hospital
# 7681  Doctor's Office  ...               Hospital
# 58     Medical Center  ...               Hospital
# 2545   Medical Center  ...               Hospital
#
# [43 rows x 14 columns]

# %% [markdown]
# #### Cluster 2 (blue): Doctor's Office (Veterinarian)

# %%
cluster2 = medical_merged.loc[medical_merged['Cluster Labels'] == 2, medical_merged.columns[[1] + list(range(5, medical_merged.shape[1]))]]
print(cluster2.shape)
cluster2
# Out:
# (55, 14)
#            categories  ... 10th Most Common Venue
# 2821  Doctor's Office  ...               Hospital
# 3081  Doctor's Office  ...               Hospital
# 3246  Doctor's Office  ...               Hospital
# 3350  Doctor's Office  ...               Hospital
# 3392  Doctor's Office  ...               Hospital
# 3613  Doctor's Office  ...               Hospital
# 3714  Doctor's Office  ...               Hospital
# 3965  Doctor's Office  ...               Hospital
# 4217  Doctor's Office  ...               Hospital
# 4303  Doctor's Office  ...               Hospital
# 4477  Doctor's Office  ...               Hospital
# 4584  Doctor's Office  ...               Hospital
# 4641  Doctor's Office  ...               Hospital
# 4737  Doctor's Office  ...               Hospital
# 4841  Doctor's Office  ...               Hospital
# 4949  Doctor's Office  ...               Hospital
# 2586  Doctor's Office  ...               Hospital
# 2786  Doctor's Office  ...               Hospital
# 2294  Doctor's Office  ...               Hospital
# 2887  Doctor's Office  ...               Hospital
# 4458  Doctor's Office  ...               Hospital
# 4528  Doctor's Office  ...               Hospital
# 5474  Doctor's Office  ...               Hospital
# 5598  Doctor's Office  ...               Hospital
# 6368  Doctor's Office  ...               Hospital
# 6438  Doctor's Office  ...               Hospital
# 6452  Doctor's Office  ...               Hospital
# 6558  Doctor's Office  ...               Hospital
# 6628  Doctor's Office  ...               Hospital
# 1770  Doctor's Office  ...               Hospital
# 1851  Doctor's Office  ...               Hospital
# 2094  Doctor's Office  ...               Hospital
# 6825  Doctor's Office  ...               Hospital
# 7277  Doctor's Office  ...               Hospital
# 7344  Doctor's Office  ...               Hospital
# 7403  Doctor's Office  ...               Hospital
# 7472  Doctor's Office  ...               Hospital
# 7878  Doctor's Office  ...               Hospital
# 7959  Doctor's Office  ...               Hospital
# 8064  Doctor's Office  ...               Hospital
# 295   Doctor's Office  ...               Hospital
# 484   Doctor's Office  ...               Hospital
# 547   Doctor's Office  ...               Hospital
# 2627  Doctor's Office  ...               Hospital
# 2943  Doctor's Office  ...               Hospital
# 3195  Doctor's Office  ...               Hospital
# 3321  Doctor's Office  ...               Hospital
# 3384  Doctor's Office  ...               Hospital
# 3447  Doctor's Office  ...               Hospital
# 3646  Doctor's Office  ...               Hospital
# 4077  Doctor's Office  ...               Hospital
# 4140  Doctor's Office  ...               Hospital
# 4203  Doctor's Office  ...               Hospital
# 4266  Doctor's Office  ...               Hospital
# 5630  Doctor's Office  ...               Hospital
#
# [55 rows x 14 columns]

# %% [markdown]
# #### Cluster 3 (green): Doctor's Office (Veterinarian)

# %%
cluster3 = medical_merged.loc[medical_merged['Cluster Labels'] == 3, medical_merged.columns[[1] + list(range(5, medical_merged.shape[1]))]]
print(cluster3.shape)
cluster3
# Out:
# (25, 14)
#                    categories  ...   10th Most Common Venue
# 1245          Doctor's Office  ...             Veterinarian
# 2077                 Hospital  ...             Veterinarian
# 4401                 Hospital  ...             Veterinarian
# 1129           Medical Center  ...             Veterinarian
# 1769                 Hospital  ...             Veterinarian
# 2409          Doctor's Office  ...             Veterinarian
# 2489          Doctor's Office  ...             Veterinarian
# 3569                 Hospital  ...             Veterinarian
# 475                  Hospital  ...  Health & Beauty Service
# 685            Medical Center  ...  Health & Beauty Service
# 1315          Doctor's Office  ...  Health & Beauty Service
# 1867                 Hospital  ...             Veterinarian
# 2077                 Hospital  ...             Veterinarian
# 2427          Doctor's Office  ...             Veterinarian
# 2575          Doctor's Office  ...  Health & Beauty Service
# 2855           Medical School  ...  Health & Beauty Service
# 3415                 Hospital  ...  Health & Beauty Service
# 5943                 Hospital  ...             Veterinarian
# 6075                 Hospital  ...  Health & Beauty Service
# 6567  Health & Beauty Service  ...                 Hospital
# 3869          Doctor's Office  ...             Veterinarian
# 5074             Optical Shop  ...             Veterinarian
# 5830                 Hospital  ...             Veterinarian
# 6011                 Hospital  ...             Veterinarian
# 6078                   Office  ...                 Hospital
#
# [25 rows x 14 columns]

# %% [markdown]
# #### Cluster 4 (orange): Doctor's Office/Hospital/Medical Center

# %%
cluster4 = medical_merged.loc[medical_merged['Cluster Labels'] == 4, medical_merged.columns[[1] + list(range(5, medical_merged.shape[1]))]]
print(cluster4.shape)
cluster4
# Out:
# (183, 14)
#             categories  ...   10th Most Common Venue
# 7       Medical Center  ...             Veterinarian
# 59      Medical Center  ...             Veterinarian
# 118     Medical Center  ...                 Hospital
# 207           Hospital  ...             Veterinarian
# 253     Medical Center  ...                 Hospital
# ...                ...  ...                      ...
# 4802          Hospital  ...  Health & Beauty Service
# 5575   Doctor's Office  ...                 Hospital
# 5936      Home Service  ...  Health & Beauty Service
# 6167  Dentist's Office  ...                 Hospital
# 6188       Medical Lab  ...  Health & Beauty Service
#
# [183 rows x 14 columns]
